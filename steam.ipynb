# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
steam_df = pd.read_csv('C:/Users/psegg/Downloads/Steam_dataset/games.csv', sep=',')

# %%
print(steam_df)
# Out:
#         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...

# %%
steam_df.head()
# Out:
#    app_id                              title date_release   win    mac  linux  \
# 0   13500  Prince of Persia: Warrior Within™   2008-11-21  True  False  False
# 1   22364            BRINK: Agents of Change   2011-08-03  True  False  False
# 2  113020       Monaco: What's Yours Is Mine   2013-04-24  True   True   True
# 3  226560                 Escape Dead Island   2014-11-18  True  False  False
# 4  249050            Dungeon of the ENDLESS™   2014-10-27  True   True  False
#
#           rating  positive_ratio  user_reviews  price_final  price_original  \
# 0  Very Positive              84          2199         9.99            9.99
# 1       Positive              85            21         2.99            2.99
# 2  Very Positive              92          3722        14.99           14.99
# 3          Mixed              61           873        14.99           14.99
# 4  Very Positive              88          8784        11.99           11.99
#
#    discount  steam_deck
# ...

# %%
steam_df.tail()
# Out:
#         app_id                                      title date_release   win  \
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
#          mac  linux           rating  positive_ratio  user_reviews  \
# 50867  False  False    Very Positive              96           101
# 50868  False  False  Mostly Negative              38         29458
# 50869  False  False    Very Positive              89          1128
# 50870  False  False    Very Positive              95            82
# 50871  False  False    Very Positive              88           144
#
#        price_final  price_original  discount  steam_deck
# ...

# %%
steam_df.describe()
# Out:
#              app_id  positive_ratio  user_reviews   price_final  \
# count  5.087200e+04    50872.000000  5.087200e+04  50872.000000
# mean   1.055224e+06       77.052033  1.824425e+03      8.620325
# std    6.103249e+05       18.253592  4.007352e+04     11.514164
# min    1.000000e+01        0.000000  1.000000e+01      0.000000
# 25%    5.287375e+05       67.000000  1.900000e+01      0.990000
# 50%    9.860850e+05       81.000000  4.900000e+01      4.990000
# 75%    1.524895e+06       91.000000  2.060000e+02     10.990000
# max    2.599300e+06      100.000000  7.494460e+06    299.990000
#
#        price_original      discount
# count    50872.000000  50872.000000
# mean         8.726788      5.592212
# std         11.507021     18.606679
# min          0.000000      0.000000
# 25%          0.990000      0.000000
# 50%          4.990000      0.000000
# 75%         11.990000      0.000000
# max        299.990000     90.000000

# %%
steam_df['positive_ratio']
# Out:
# 0        84
# 1        85
# 2        92
# 3        61
# 4        88
#          ..
# 50867    96
# 50868    38
# 50869    89
# 50870    95
# 50871    88
# Name: positive_ratio, Length: 50872, dtype: int64

# %%
steam_df[['positive_ratio', 'user_reviews', 'price_original']]
# Out:
#        positive_ratio  user_reviews  price_original
# 0                  84          2199            9.99
# 1                  85            21            2.99
# 2                  92          3722           14.99
# 3                  61           873           14.99
# 4                  88          8784           11.99
# ...               ...           ...             ...
# 50867              96           101            0.00
# 50868              38         29458            0.00
# 50869              89          1128            0.00
# 50870              95            82            0.00
# 50871              88           144            0.00
#
# [50872 rows x 3 columns]

# %%
steam_df.keys()
# Out:
# Index(['app_id', 'title', 'date_release', 'win', 'mac', 'linux', 'rating',
#        'positive_ratio', 'user_reviews', 'price_final', 'price_original',
#        'discount', 'steam_deck'],
#       dtype='object')

# %%
steam_df.columns
# Out:
# Index(['app_id', 'title', 'date_release', 'win', 'mac', 'linux', 'rating',
#        'positive_ratio', 'user_reviews', 'price_final', 'price_original',
#        'discount', 'steam_deck'],
#       dtype='object')

# %%
steam_df['title'].unique()
# Out:
# array(['Prince of Persia: Warrior Within™', 'BRINK: Agents of Change',
#        "Monaco: What's Yours Is Mine", ..., 'Eternights',
#        'Forgive Me Father 2', 'FatalZone'], dtype=object)

# %%
steam_df['title'].value_counts()
# Out:
# title
# Loop                              4
# Dark Matter                       3
# Cursed                            3
# Beyond the Wall                   3
# Outpost                           3
#                                  ..
# Wasteland Survival                1
# 变量 Variables                      1
# GENSOU Skydrift                   1
# Mutant Year Zero: Seed of Evil    1
# FatalZone                         1
# Name: count, Length: 50751, dtype: int64

# %%
steam_df['win'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='win'>

# %%
steam_df.to_csv('C:/Users/psegg/Documents/steam.csv', sep=',')

# %%
steam_df.describe()
# Out:
#              app_id  positive_ratio  user_reviews   price_final  \
# count  5.087200e+04    50872.000000  5.087200e+04  50872.000000
# mean   1.055224e+06       77.052033  1.824425e+03      8.620325
# std    6.103249e+05       18.253592  4.007352e+04     11.514164
# min    1.000000e+01        0.000000  1.000000e+01      0.000000
# 25%    5.287375e+05       67.000000  1.900000e+01      0.990000
# 50%    9.860850e+05       81.000000  4.900000e+01      4.990000
# 75%    1.524895e+06       91.000000  2.060000e+02     10.990000
# max    2.599300e+06      100.000000  7.494460e+06    299.990000
#
#        price_original      discount
# count    50872.000000  50872.000000
# mean         8.726788      5.592212
# std         11.507021     18.606679
# min          0.000000      0.000000
# 25%          0.990000      0.000000
# 50%          4.990000      0.000000
# 75%         11.990000      0.000000
# max        299.990000     90.000000

# %%
steam_df['price_original']
# Out:
# 0         9.99
# 1         2.99
# 2        14.99
# 3        14.99
# 4        11.99
#          ...
# 50867     0.00
# 50868     0.00
# 50869     0.00
# 50870     0.00
# 50871     0.00
# Name: price_original, Length: 50872, dtype: float64

# %%
steam_df['price_original'] + 10
# Out:
# 0        19.99
# 1        12.99
# 2        24.99
# 3        24.99
# 4        21.99
#          ...
# 50867    10.00
# 50868    10.00
# 50869    10.00
# 50870    10.00
# 50871    10.00
# Name: price_original, Length: 50872, dtype: float64

# %%
steam_df['price_original'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='price_original'>

# %%
steam_df['new'] = np.nan
steam_df['price_original+100'] = steam_df['price_original'] + 100

# %%
steam_df['First+Final+Sale'] = steam_df['price_original'] + steam_df['price_final'] + steam_df['discount']

# %%
steam_df.head()
# Out:
#    app_id                              title date_release   win    mac  linux  \
# 0   13500  Prince of Persia: Warrior Within™   2008-11-21  True  False  False
# 1   22364            BRINK: Agents of Change   2011-08-03  True  False  False
# 2  113020       Monaco: What's Yours Is Mine   2013-04-24  True   True   True
# 3  226560                 Escape Dead Island   2014-11-18  True  False  False
# 4  249050            Dungeon of the ENDLESS™   2014-10-27  True   True  False
#
#           rating  positive_ratio  user_reviews  price_final  price_original  \
# 0  Very Positive              84          2199         9.99            9.99
# 1       Positive              85            21         2.99            2.99
# 2  Very Positive              92          3722        14.99           14.99
# 3          Mixed              61           873        14.99           14.99
# 4  Very Positive              88          8784        11.99           11.99
#
# ...

# %%
steam_df.keys()
# Out:
# Index(['app_id', 'title', 'date_release', 'win', 'mac', 'linux', 'rating',
#        'positive_ratio', 'user_reviews', 'price_final', 'price_original',
#        'discount', 'steam_deck', 'new', 'price_original+100',
#        'First+Final+Sale'],
#       dtype='object')

# %%
steam_df.drop(['new', 'price_original+100'], axis=1)
# Out:
#         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...

# %%
steam_df.head()
# Out:
#    app_id                              title date_release   win    mac  linux  \
# 0   13500  Prince of Persia: Warrior Within™   2008-11-21  True  False  False
# 1   22364            BRINK: Agents of Change   2011-08-03  True  False  False
# 2  113020       Monaco: What's Yours Is Mine   2013-04-24  True   True   True
# 3  226560                 Escape Dead Island   2014-11-18  True  False  False
# 4  249050            Dungeon of the ENDLESS™   2014-10-27  True   True  False
#
#           rating  positive_ratio  user_reviews  price_final  price_original  \
# 0  Very Positive              84          2199         9.99            9.99
# 1       Positive              85            21         2.99            2.99
# 2  Very Positive              92          3722        14.99           14.99
# 3          Mixed              61           873        14.99           14.99
# 4  Very Positive              88          8784        11.99           11.99
#
# ...

# %%
steam_df = steam_df.drop(['new', 'price_original+100'], axis=1)

# %%
steam_df.head()
# Out:
#    app_id                              title date_release   win    mac  linux  \
# 0   13500  Prince of Persia: Warrior Within™   2008-11-21  True  False  False
# 1   22364            BRINK: Agents of Change   2011-08-03  True  False  False
# 2  113020       Monaco: What's Yours Is Mine   2013-04-24  True   True   True
# 3  226560                 Escape Dead Island   2014-11-18  True  False  False
# 4  249050            Dungeon of the ENDLESS™   2014-10-27  True   True  False
#
#           rating  positive_ratio  user_reviews  price_final  price_original  \
# 0  Very Positive              84          2199         9.99            9.99
# 1       Positive              85            21         2.99            2.99
# 2  Very Positive              92          3722        14.99           14.99
# 3          Mixed              61           873        14.99           14.99
# 4  Very Positive              88          8784        11.99           11.99
#
# ...

# %%
steam_df[steam_df['positive_ratio'] > 85]
# Out:
#         app_id                                      title date_release   win  \
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# 5       250180                               METAL SLUG 3   2015-09-14  True
# 8       282900          Hyperdimension Neptunia Re;Birth1   2015-01-29  True
# 13       29180                                      Osmos   2009-08-18  True
# ...        ...                                        ...          ...   ...
# 50861  2518220       Bomb Rush Cyberfunk DLC - Base & Jay   2023-08-18  True
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...

# %%
steam_df[steam_df['rating'] == 'Positive']
# Out:
#         app_id                                          title date_release  \
# 1        22364                        BRINK: Agents of Change   2011-08-03
# 30      458790  The House in Fata Morgana Original Soundtrack   2016-05-13
# 31      462280      Offworld Trading Company - Soundtrack DLC   2016-04-28
# 58      393831           Magicka 2: Three Cardinals Robe Pack   2015-09-15
# 61      434041    Mordheim: City of the Damned - The Smuggler   2016-02-04
# ...        ...                                            ...          ...
# 50805  1588720                           Ion Fury: Aftershock   2023-10-02
# 50811  1845670                          Islands of the Caliph   2023-09-29
# 50820  2002870     Rhapsody II: Ballad of the Little Princess   2023-08-29
# 50839  2380280            Let's Build a Zoo: Aquarium Odyssey   2023-08-17
# 50854  2502240                       Planet Zoo: Oceania Pack   2023-09-19
#
# ...

# %%
steam_df[(steam_df['rating'] == 'Very Positive')&(steam_df['win'] == False)]
# Out:
#         app_id                                              title  \
# 180     453400             Squad - Original Soundtrack Vol. 1 & 2
# 219    1600150                        Tiny Bunny: Full Soundtrack
# 348    1232520                           Wish Original Soundtrack
# 776    1247270     Divinity: Original Sin 2 - Official Soundtrack
# 910     322660         The Binding of Isaac: Rebirth - Soundtrack
# ...        ...                                                ...
# 46352  2344510                      Pineapple on pizza Soundtrack
# 46463   361700                              Mortal Kombat: Legacy
# 46602  1421480               Mafia: Definitive Edition Soundtrack
# 48098   802640  Deep Rock Galactic - Original Soundtrack Volum...
# 50618  1986820                       POSTAL - Official Soundtrack
#
#       date_release    win    mac  linux         rating  positive_ratio  \
# 180     2016-04-29  False  False  False  Very Positive              93
# ...

# %%
len(steam_df)
# Out:
# 50872

# %%
steam_df.shape[0]
# Out:
# 50872

# %%
# steam_df.count()[0]
# Out:
# C:\Users\psegg\AppData\Local\Temp\ipykernel_31776\2412191028.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   steam_df.count()[0]
# 50872

# %%
steam_df.count()['title']
# Out:
# 50872

# %%
steam_df.sort_values(by=['positive_ratio/price_final'], ascending=False)[0:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31776\2158321722.py in ?()
# ----> 1 steam_df.sort_values(by=['positive_ratio/price_final'], ascending=False)[0:10]
#
# c:\Users\psegg\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# c:\Users\psegg\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
# ...

# %%
steam_df.columns.tolist()
# Out:
# ['app_id',
#  'title',
#  'date_release',
#  'win',
#  'mac',
#  'linux',
#  'rating',
#  'positive_ratio',
#  'user_reviews',
#  'price_final',
#  'price_original',
#  'discount',
#  'steam_deck',
#  'First+Final+Sale']

# %%
steam_df.get('positive_ratio/price_final')

# %%
steam_df.head(10)
# Out:
#    app_id                                              title date_release  \
# 0   13500                  Prince of Persia: Warrior Within™   2008-11-21
# 1   22364                            BRINK: Agents of Change   2011-08-03
# 2  113020                       Monaco: What's Yours Is Mine   2013-04-24
# 3  226560                                 Escape Dead Island   2014-11-18
# 4  249050                            Dungeon of the ENDLESS™   2014-10-27
# 5  250180                                       METAL SLUG 3   2015-09-14
# 6  253980                                            Enclave   2013-10-04
# 7  271850  Men of War: Assault Squad 2 - Deluxe Edition u...   2014-05-16
# 8  282900                  Hyperdimension Neptunia Re;Birth1   2015-01-29
# 9   19810                               The Sum of All Fears   2008-10-10
#
#     win    mac  linux           rating  positive_ratio  user_reviews  \
# 0  True  False  False    Very Positive              84          2199
# ...

# %%
steam_df.sort_values(by='positive_ratio/price_final', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31776\762468868.py in ?()
# ----> 1 steam_df.sort_values(by='positive_ratio/price_final', ascending=False).head(10)
#
# c:\Users\psegg\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# c:\Users\psegg\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
# ...

# %%
steam_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50872 entries, 0 to 50871
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   app_id            50872 non-null  int64
#  1   title             50872 non-null  object
#  2   date_release      50872 non-null  object
#  3   win               50872 non-null  bool
#  4   mac               50872 non-null  bool
#  5   linux             50872 non-null  bool
#  6   rating            50872 non-null  object
#  7   positive_ratio    50872 non-null  int64
#  8   user_reviews      50872 non-null  int64
#  9   price_final       50872 non-null  float64
#  10  price_original    50872 non-null  float64
#  11  discount          50872 non-null  float64
#  12  steam_deck        50872 non-null  bool
#  13  First+Final+Sale  50872 non-null  float64
# dtypes: bool(4), float64(4), int64(3), object(3)
# memory usage: 4.1+ MB

# %%
steam_df.sort_values(by='positive_ratio/price_final', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31776\762468868.py in ?()
# ----> 1 steam_df.sort_values(by='positive_ratio/price_final', ascending=False).head(10)
#
# c:\Users\psegg\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# c:\Users\psegg\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
# ...

# %%
steam_df.dtypes
# Out:
# app_id                int64
# title                object
# date_release         object
# win                    bool
# mac                    bool
# linux                  bool
# rating               object
# positive_ratio        int64
# user_reviews          int64
# price_final         float64
# price_original      float64
# discount            float64
# steam_deck             bool
# First+Final+Sale    float64
# dtype: object

# %%
steam_df['positive_ratio/price_final'] = steam_df['positive_ratings'] / steam_df['price_final']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\psegg\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'positive_ratings'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 42 line 1
# ...

# %%
steam_df.hist()
# Out:
# array([[<Axes: title={'center': 'app_id'}>,
#         <Axes: title={'center': 'positive_ratio'}>,
#         <Axes: title={'center': 'user_reviews'}>],
#        [<Axes: title={'center': 'price_final'}>,
#         <Axes: title={'center': 'price_original'}>,
#         <Axes: title={'center': 'discount'}>],
#        [<Axes: title={'center': 'First+Final+Sale'}>, <Axes: >, <Axes: >]],
#       dtype=object)
